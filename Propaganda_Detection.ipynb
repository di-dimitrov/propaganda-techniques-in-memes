# %%
# !git clone https://github.com/di-dimitrov/mmf_propaganda.git
# !pip install torch==1.6.0+cu101 torchvision==0.7.0+cu101 -f https://download.pytorch.org/whl/torch_stable.html

# %cd mmf
# !pip install --editable .

# %%
# !mkdir -p /root/.cache/torch/mmf/data/
# !cp -r ./data/. /root/.cache/torch/mmf/data/

# %%
# !rm -rf /usr/local/lib/python2.7 /swift /usr/local/cuda-10.0 /tensorflow-1.15.2/ /content/sample_data/

# %% [markdown]
# ### ViLBERT

# %%
# !mmf_run config=./projects/propaganda/configs/vilbert/direct.yaml \
datasets=propaganda \
model=vilbert

# %% [markdown]
# ### Visual BERT

# %%
 # !mmf_run config=./projects/propaganda/configs/visual_bert/direct.yaml \
 datasets=propaganda \
 model=visual_bert

# %% [markdown]
# ## If you want to run the other models in the paper, please `run` the cells below:

# %% [markdown]
# #### BERT

# %%
# !mmf_run config=./projects/others/unimodal/configs/propaganda/bert.yaml datasets=propaganda model=unimodal_text

# %% [markdown]
# #### Late Fusion

# %%
# !mmf_run config=./projects/others/late_fusion/propaganda/defaults.yaml datasets=propaganda model=late_fusion

# %% [markdown]
# #### Concat_BERT

# %%
# !mmf_run config=./projects/others/concat_bert/propaganda/defaults.yaml datasets=propaganda model=concat_bert

# %% [markdown]
# #### MMBT

# %%
# !mmf_run config=./projects/mmbt/configs/propaganda/with_features.yaml datasets=propaganda model=mmbt
